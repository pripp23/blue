# %%
import pandas as pd
import numpy as np
df = pd.read_csv("AY 22 BLUE survey data_FALL ONLY.csv")
df = df.drop(axis = 0, index = [0,1,2])
df['RecordedDate'] = pd.to_datetime(df['RecordedDate']).dt.date
df = df[['RecordedDate', 'Q4', 'Q5', 'Q6', 'Q14',
       'Q8_1', 'Q8_2', 'Q8_3', 'Q8_4', 'Q8_5', 'Q8_6', 'Q8_7', 'Q8_8', 'Q16',
       'Q17', 'Q19', 'Q20', 'Q21', 'Q22', 'Q23', 'Q25_1', 'Q24', 'Q16.1', 'Q9',
       'Q10', 'Q26_1', 'Q26_2', 'Q26_3', 'Q26_4', 'Q26_5', 'Q26_6', 'Q12',
       'Q9 - Parent Topics', 'Q9 - Sentiment Polarity', 'Q9 - Sentiment Score',
       'Q9 - Sentiment', 'Q9 - Topic Sentiment Label',
       'Q9 - Topic Sentiment Score', 'Q9 - Topics']]
df
# Out:
#     RecordedDate                           Q4                     Q5  \
# 3     2021-09-13                       Rowing                 Junior
# 4     2021-09-13                       Rowing                 Junior
# 5     2021-09-13             CC/Track & Field                 Junior
# 6     2021-09-13               Women's Tennis                 Junior
# 7     2021-09-13               Men's Lacrosse                 Junior
# ..           ...                          ...                    ...
# 411   2021-12-01             Men's Basketball  First-Year / Freshman
# 412   2021-12-02  Women's Swimming and Diving  First-Year / Freshman
# 413   2021-12-06               Men's Lacrosse  First-Year / Freshman
# 414   2021-12-08             CC/Track & Field  First-Year / Freshman
# 415   2021-12-08               Women's Soccer  First-Year / Freshman
#
#                                      Q6  \
# 3                          Branding You
# 4                          Branding You
# ...

# %%
df.to_csv("/Users/peterripperger/Desktop/Fall_2022.csv")

# %%
df['RecordedDate'] = pd.to_datetime(df['RecordedDate']).dt.date
df
# Out:
#            StartDate          EndDate      Status        IPAddress Progress  \
# 3    9/13/2021 17:59  9/13/2021 18:01  IP Address    128.4.181.241      100
# 4    9/13/2021 18:02  9/13/2021 18:03  IP Address  174.198.210.161      100
# 5    9/13/2021 18:02  9/13/2021 18:03  IP Address      128.4.75.59      100
# 6    9/13/2021 18:02  9/13/2021 18:03  IP Address    107.77.203.93      100
# 7    9/13/2021 18:02  9/13/2021 18:03  IP Address      128.4.81.82      100
# ..               ...              ...         ...              ...      ...
# 411  12/1/2021 11:22  12/1/2021 11:24  IP Address     128.4.154.81      100
# 412  12/2/2021 12:30  12/2/2021 12:32  IP Address    128.4.144.212      100
# 413  12/1/2021 11:29  12/6/2021 16:46  IP Address      128.4.76.99      100
# 414   12/1/2021 9:49   12/1/2021 9:50  IP Address   107.77.204.111       40
# 415  12/1/2021 14:53  12/1/2021 14:56  IP Address     128.4.107.66       24
#
# ...

# %%
df['Q8_2']
# Out:
# 3             Neutral
# 4      Strongly agree
# 5      Strongly agree
# 6      Strongly agree
# 7               Agree
#             ...
# 411             Agree
# 412             Agree
# 413             Agree
# 414    Strongly agree
# 415               NaN
# Name: Q8_2, Length: 413, dtype: object

# %%
df = df[['RecordedDate','Q15', 'Q4', 'Q5', 'Q6', 'Q14',
       'Q8_1', 'Q8_2', 'Q8_3', 'Q8_4', 'Q8_5', 'Q8_6', 'Q8_7', 'Q8_8', 'Q16',
       'Q17', 'Q19', 'Q20', 'Q21', 'Q22', 'Q23', 'Q25_1', 'Q24', 'Q16.1', 'Q9',
       'Q10', 'Q26_1', 'Q26_2', 'Q26_3', 'Q26_4', 'Q26_5', 'Q26_6', 'Q12',
       'Q9 - Parent Topics', 'Q9 - Sentiment Polarity', 'Q9 - Sentiment Score',
       'Q9 - Sentiment', 'Q9 - Topic Sentiment Label',
       'Q9 - Topic Sentiment Score', 'Q9 - Topics']]

# %%
df
# Out:
#     RecordedDate        Q15                           Q4  \
# 3     2021-09-13  702515979                       Rowing
# 4     2021-09-13  702506825                       Rowing
# 5     2021-09-13  702527168             CC/Track & Field
# 6     2021-09-13  702525158               Women's Tennis
# 7     2021-09-13  702505866               Men's Lacrosse
# ..           ...        ...                          ...
# 411   2021-12-01  702614972             Men's Basketball
# 412   2021-12-02  702591628  Women's Swimming and Diving
# 413   2021-12-06  702587736               Men's Lacrosse
# 414   2021-12-08  702587259             CC/Track & Field
# 415   2021-12-08  702585249               Women's Soccer
#
#                         Q5                                  Q6  \
# 3                   Junior                        Branding You
# 4                   Junior                        Branding You
# 5                   Junior                        Branding You
# ...
