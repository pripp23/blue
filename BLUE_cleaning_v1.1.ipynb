# %%
import pandas as pd
import numpy as np
df = pd.read_csv("AY 18 BLUE data_FALL ONLY.csv")
df = df.drop(axis = 0, index = [0,1,2])
#df = df.drop(axis = 1, index = [0,1,2,3,4,5,6,8,9,10,11,12])
df['RecordedDate'] = pd.to_datetime(df['RecordedDate']).dt.date
df = df.drop(df.columns[[0,1,2,3,4,5,6,8,9,10,11,12,13,14,15,16]], axis = 1)
df['RecordedDate'] = pd.to_datetime(df['RecordedDate']).dt.date
df
# Out:
#    RecordedDate             Q4                 Q5  \
# 3    2017-09-22       swimming           Freshman
# 4    2017-09-22       Softball             Senior
# 5    2017-09-22       Baseball  5th Gear/Graduate
# 6    2017-09-22         Rowing             Senior
# 7    2017-09-22            Wbb             Junior
# ..          ...            ...                ...
# 95   2017-11-27       Lacrosse             Senior
# 96   2017-11-27  Womens tennis             Senior
# 97   2017-11-27         Rowing             Senior
# 98   2017-11-27       Baseball             Senior
# 99   2017-11-27         Tennis             Senior
#
#                               Q6               Q8_1               Q8_2  \
# 3          Healthy Relationships           Disagree              Agree
# 4             Financial Literacy  Strongly DIsagree  Strongly DIsagree
# 5             Financial Literacy  Strongly DIsagree  Strongly DIsagree
# 6             Financial Literacy  Strongly DIsagree  Strongly DIsagree
# ...

# %%
df.to_csv("2018F_cleaned.csv")
